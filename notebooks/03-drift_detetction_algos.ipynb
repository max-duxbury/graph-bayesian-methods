# %% [markdown]
# **Graph Signal Reconstruction & Denoising/Total Variation/Spectral Anomaly Detection**
#
# We are given a trustworthy subset of nodes (passing CUSUM (`TODO:` look at alternative tests also)). We can reconstruct the signal via the _bandlimited graph signal sampling theorem_. `TODO:` Look at using Chebyshev polynomial filters for spectral anomaly detection and TV denoising.
